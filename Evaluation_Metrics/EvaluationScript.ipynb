# %%
# !cp /content/drive/MyDrive/SPML-Thesis_Data/Evaluation_Metrics/evaluationMetrics.py .
from evaluationMetrics import Score_Similarity_Evaluator
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import single_meteor_score
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def getBLEUScore(pred_answer, answer):
  max_bleu_score = 0

  candidate = nltk.word_tokenize(answer.lower().replace(".", " ")) #lowercasing and removing fullstop
  if type(pred_answer) != list:
    pred_answer = [pred_answer]
  assert type(pred_answer) == list, pred_answer+' of type ->'+type(pred_answer)
  print(pred_answer)
  for ans in pred_answer:
    reference = [nltk.word_tokenize(ans.lower().replace(".", " "))] #lowercasing and removing fullstop
    print(candidate)
    smooth_fn = SmoothingFunction().method1
    print('d')
    bleu_score = sentence_bleu(reference, candidate, smoothing_function=smooth_fn, weights=(1, 0, 0, 0))

    if bleu_score > max_bleu_score:
      max_bleu_score = bleu_score
      
  return max_bleu_score

def getMeteorScore(pred_answer, answer):
  #split actual answer to serve as candidate for BLEU score
  max_meteor_score = 0
  reference = nltk.word_tokenize(answer.lower().replace(".", " ")) #lowercasing and removing fullstop
  if type(pred_answer) != list:
    pred_answer = [pred_answer]
  assert type(pred_answer) == list, pred_answer+' of type ->'+type(pred_answer)
  for ans in pred_answer:
    candidate = nltk.word_tokenize(ans.lower().replace(".", " ")) #lowercasing and removing fullstop
    meteor_score = single_meteor_score(reference, candidate)
    if meteor_score > max_meteor_score:
      max_meteor_score = meteor_score
  return max_meteor_score

# %% [markdown]
# # Classifier

# %% [markdown]
# ## IMG+BOW

# %% [markdown]
# ### COCOQA Test Set

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-COCOQA_TestSet.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'where are fruits vegetables and mushrooms assorted',
#  'Image_Id': '63668',
#  'Question_Type': 3,
#  'Ground_Truth': 'container',
#  'Prediction': 'box'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 38948/38948 [00:27<00:00, 1438.66it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-COCOQA_TestSet - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### Three Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-Three_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'two'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1649.53it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-Three_Question_Types-One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### Four Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-Four_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'two'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1738.16it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_IMG+BOW_output-Four_Question_Types-One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## VIS+LSTM

# %% [markdown]
# ### COCOQA Test Set

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-COCOQA_TestSet.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'what parked at curbed on tree lined street',
#  'Image_Id': '239676',
#  'Question_Type': 0,
#  'Ground_Truth': 'buses',
#  'Prediction': 'buses'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 38948/38948 [00:19<00:00, 1991.05it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-COCOQA_TestSet - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### Three Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-Three_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1704.70it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-Three_Question_Types-One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### Four Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-Four_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1925.86it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Classifier Results/Classifier_VIS-LSTM_output-Four_Question_Types-One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# # OFA

# %% [markdown]
# ## Three Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Three_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 2077.64it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Three_Question_Types One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## Three Category: Multi Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Three_Question_Types Multi_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1991.25it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Three_Question_Types Multi_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## Four Category: One Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Four_Question_Types One_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1926.82it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Four_Question_Types One_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## Four Category: Multi Word Answer

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Four_Question_Types Multi_Word_Answer.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': '1653556733',
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': 'three'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1874.68it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Four_Question_Types Multi_Word_Answer - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## Template

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Templates_Unseen_Dataset.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'Where is the cat?',
#  'Image_Id': '169365',
#  'Question_Type': 3,
#  'Ground_Truth': 'sink',
#  'Prediction': 'on the sink'}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 161/161 [00:00<00:00, 1738.76it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Templates_Unseen_Dataset - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## COCOQA Test Set - Classifier Dataset

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Classifier_Unseen_Dataset.pkl", "rb"))

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 38948/38948 [00:23<00:00, 1660.39it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/OFA Results/OFA_output-Classifier_Unseen_Dataset - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# # Templates

# %% [markdown]
# ## YOLO

# %% [markdown]
# ### Templates Unseen

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output-Unseen_Dataset.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'Where is the cat?',
#  'Image_Id': 135414,
#  'Question_Type': 3,
#  'Ground_Truth': 'sink',
#  'Prediction': []}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 161/161 [00:00<00:00, 1635.72it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output- Templates_Unseen_Dataset - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Single Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output-Three_Question_Types_OneWord.pkl", "rb"))

# %%
predans[-108]
# Out:
# {'Question': 'where is the bowl?',
#  'Image_Id': 1765,
#  'Question_Type': 3,
#  'Ground_Truth': 'plate',
#  'Prediction': ['The orange.',
#   'Orange.',
#   ' the orange.',
#   ' a orange.',
#   ' an orange.']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1812.31it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output-Three_Question_Types_OneWord - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Multi Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output-Three_Question_Types_MultiWord.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': 973,
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': ['Zero']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1690.47it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_YOLO_output-Three_Question_Types_MultiWord - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## SSD

# %% [markdown]
# ### Templates Unseen

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output-Unseen_Dataset.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'Where is the cat?',
#  'Image_Id': 135414,
#  'Question_Type': 3,
#  'Ground_Truth': 'sink',
#  'Prediction': ['The sink.', 'Sink.', ' the sink.', ' a sink.', ' an sink.']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 161/161 [00:00<00:00, 2108.99it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output- Templates_Unseen_Dataset - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Single Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output-Three_Question_Types_OneWord.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': 973,
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': ['Zero']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1688.11it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output-Three_Question_Types_OneWord - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Multi Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output-Three_Question_Types_MultiWord.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': 973,
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': ['Zero']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1541.74it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_SSD_output-Three_Question_Types_MultiWord - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ## Center Net

# %% [markdown]
# ### Templates Unseen

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output-Unseen_Dataset.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'Where is the cat?',
#  'Image_Id': 135414,
#  'Question_Type': 3,
#  'Ground_Truth': 'sink',
#  'Prediction': []}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 161/161 [00:00<00:00, 1437.79it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output- Templates_Unseen_Dataset - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Single Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output-Three_Question_Types_OneWord.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': 973,
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': ['Zero']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1768.98it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output-Three_Question_Types_OneWord - with_Evaluation.pkl", "wb"), protocol=2)

# %% [markdown]
# ### AL-VQA Three Types Multi Word

# %%
import pickle
from tqdm import tqdm

predans = pickle.load(open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output-Three_Question_Types_MultiWord.pkl", "rb"))

# %%
predans[0]
# Out:
# {'Question': 'how many books are on the floor?',
#  'Image_Id': 973,
#  'Question_Type': 1,
#  'Ground_Truth': 'four',
#  'Prediction': ['Zero']}

# %%
for output in tqdm(predans):
  answer = output['Ground_Truth']
  pred_answer = output['Prediction']
  output['Evaluation_Metric'] = Score_Similarity_Evaluator(pred_answer, answer)
# Out:
# 100%|██████████| 900/900 [00:00<00:00, 1728.54it/s]

# %%
pickle.dump(predans, open("/content/drive/MyDrive/SPML-Thesis_Data/Results/Templates Results/Templates_centerNet_output-Three_Question_Types_MultiWord - with_Evaluation.pkl", "wb"), protocol=2)
